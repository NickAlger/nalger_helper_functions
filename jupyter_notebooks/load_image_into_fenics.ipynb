# %%
import dolfin as dl
import matplotlib.pyplot as plt

from nalger_helper_functions import load_image_into_fenics


mesh = dl.UnitSquareMesh(100, 103)
V = dl.FunctionSpace(mesh, 'CG', 2)

u = load_image_into_fenics(V, 'angel_peak_badlands.png')

cm = dl.plot(u)
plt.colorbar(cm)
